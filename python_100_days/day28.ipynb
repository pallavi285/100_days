# %% [markdown]
# # Inheritance part 2

# %% [markdown]
# **Can a child class override a Parent method?**
#
# Yes - if a method with the same name is defined in the child class,it overrides the parent's version.

# %% [markdown]
# **Does Python support multiple inheritance?**
#
# Yes , Python support multiple inheritance.

# %% [markdown]
# **What is MRO?     (Method Resolution Order)**
#
# It's the order in which python looks for a method in case of multiple inheritance, followin the C3 linearization rule.

# %% [markdown]
# **What the difference between composition and inheritance?**
#
# Inheritance is "is-a" relationship; composition is "has-a" relationship
# (e.g., Car has a Engine)
