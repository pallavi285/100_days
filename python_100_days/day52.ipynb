# %%
import math

# %% [markdown]
# ## math.fabs(x)
#
# Returns absolute value (float).
# Better than abs() when you want float output.

# %%
math.fabs(-5)
# Out:
# 5.0

# %% [markdown]
# ## math.gcd(a, b)
#
# Finds greatest common divisor — very important in DSA.

# %%
math.gcd(12, 18)
# Out:
# 6

# %% [markdown]
# ## math.pi & math.e
#
# Important constants.

# %%
print(math.pi)
print(math.e)
# Out:
# 3.141592653589793
# 2.718281828459045
