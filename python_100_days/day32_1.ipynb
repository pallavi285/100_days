# %% [markdown]
# # Amortized time complexity

# %% [markdown]
# Python lists are dynamic arrays.
# When you do append(), it feels like constant time because Python uses overallocation.
#
# 👉 What happens?
#
# When the list gets full, Python creates a bigger array
#
# It copies old elements
#
# Then continues appending fast again
#
# This expensive copy happens rarely… so if you look at many operations together:
#
# ✔ The average cost per append = O(1) amortized
#
# Even though some appends cost O(n) individually!
