# %%
import math

# %% [markdown]
# ## math.log(x, base)
#
# Logarithm.

# %%
math.log(8, 2)
# Out:
# 3.0

# %% [markdown]
# ## math.sin(), cos(), tan()
#
# Trigonometric functions (use radians).

# %%
math.sin(math.pi/2)
# Out:
# 1.0

# %%
math.cos(0)
# Out:
# 1.0
