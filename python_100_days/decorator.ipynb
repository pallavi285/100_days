# %%
def update(func):
    def wrapper(N):
        out = []
        for i in range(N):
            if i % 2 ==0:
                out.append(i**3)
            else:
                out.append(i**2)
        return out
    return wrapper
@update
def fun(N):
    if N%2 == 0 :
        return N**2 
    else:
        return N**3    
print(fun(5))
# Out:
# 125
