# %% [markdown]
# # OrderDict

# %%
from collections import OrderedDict

# %%
od = OrderedDict()

# %%
print(od)
# Out:
# OrderedDict()

# %%
type(od)
# Out:
# collections.OrderedDict

# %% [markdown]
# #### OrderedDict is a subclass of Python’s built-in dictionary dict

# %%
# Check if OrderedDict is a subclass of dict
print(issubclass(OrderedDict, dict))  # True
# Out:
# True
