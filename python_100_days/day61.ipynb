# %% [markdown]
# # NumPy in Python 🔢

# %% [markdown]
# ## NumPy (Numerical Python)
# is a **core Python library** used for **fast numerical computation.**
#
# It is especially important for Data Science, Machine Learning, AI, and scientific computing.
#
# `Why NumPy is important`
#
# - Much faster than Python lists
#
# - Uses less memory
#
# - Supports vectorized operations (no loops needed)
#
# - Foundation of Pandas, Scikit-learn, TensorFlow

# %% [markdown]
# **Useful in real life**
#
# - Image processing 📸
#
# - Data analysis 📊
#
# - Machine learning 🤖
#
# - Statistics & simulations
#
# - Engineering & research
