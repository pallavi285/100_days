# %% [markdown]
# # raise()

# %% [markdown]
# raise is used to manually throw an error when something is wrong.

# %%
def read_file(filename):
    if not filename.endswith(".txt"):
        raise TypeError("Only .txt files are allowed!")
    
    with open(filename, "r") as f:
        return f.read()

# %%
raise TypeError("Wrong type")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 raise TypeError("Wrong type")
#
# TypeError: Wrong type

# %%
raise ValueError("Invalid value")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 raise ValueError("Invalid value")
#
# ValueError: Invalid value

# %%
raise ZeroDivisionError("Cannot divide by zero")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 raise ZeroDivisionError("Cannot divide by zero")
#
# ZeroDivisionError: Cannot divide by zero

# %%
raise RuntimeError("Something bad happened")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 raise RuntimeError("Something bad happened")
#
# RuntimeError: Something bad happened

# %%
age = -5

if age < 0:
    raise ValueError("Age cannot be negative")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 4
#       1 age = -5
#       3 if age < 0:
# ----> 4     raise ValueError("Age cannot be negative")
#
# ValueError: Age cannot be negative
