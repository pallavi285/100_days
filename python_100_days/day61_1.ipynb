# %% [markdown]
# # About NumPy Array (ndarray)

# %% [markdown]
# ### 1. Homogeneous

# %% [markdown]
# 👉 All elements are of same data type

# %%
import numpy as np

# %%
a = np.array([1,3,5])
a.dtype # here dtype is attribute or property
# Out:
# dtype('int32')

# %%
b = np.array([1,3.0,5])
b.dtype
# Out:
# dtype('float64')

# %% [markdown]
# ### 2. Stored in Contiguous Memory
#
# 👉 Elements are stored next to each other in memory
#
# 📌 This is why NumPy is very fast compared to lists.

# %% [markdown]
# ### 3. Fixed Size
#
# 👉 Size of ndarray is fixed after creation

# %% [markdown]
# ### 4. Supports Vectorized Operations
#
# 👉 Operations apply to all elements at once

# %% [markdown]
# ### 5. Multidimensional
#
# 👉 Can be 1D, 2D, 3D, …
#
# Used for:
#
# vectors (1D)
#
# matrices (2D)
#
# images / tensors (3D+)

# %% [markdown]
# ### 6. Memory Efficient
#
# 👉 Uses less memory than Python lists
#
# Because:
#
# Same data type
#
# Contiguous storage

# %% [markdown]
# ### 7. Supports Broadcasting
#
#
# Broadcasting in NumPy refers to the ability to perform arithmetic operations on arrays of different shapes
#
# 👉 Arrays of different shapes can interact

# %%
a + 5
# Out:
# array([ 6,  8, 10])
