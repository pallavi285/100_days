# %%
def functionA(func):
    def inner_function():
        p1 = 'This is print1'
        print(func())
        p2 = 'This is print2'
        return p1 , p2
    return inner_function

@functionA
def functionB():
    return 'This is functionB'

# %%
print(functionB())
# Out:
# This is functionB
# ('This is print1', 'This is print2')
